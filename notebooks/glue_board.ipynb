# %% [markdown]
# # Imports

# %%
import pandas as pd
import matplotlib.pyplot as plt
import re
import os
import numpy as np
from collections import defaultdict
import json

# %%
def get_value_tuple(pos: int, elem: float, n: int) -> tuple:
    return tuple([0] * pos + [elem] + [0] * (n - pos - 1))

# %%
result_json = json.load(open("/home/philko/Documents/Uni/WiSe2223/UnsupervisedLearning/udl-negation/GLUEResults.json", 'r'))

# %% [markdown]
# # MRPC

# %%
result_json['mrpc']
# Out:
# {'ours': {'accuracy': 0.6617647058823529, 'f1': 0.7570422535211268},
#  'theirs': {'accuracy': 0.7916666666666666, 'f1': 0.8590381426202321}}

# %%
import matplotlib.pyplot as plt
import numpy as np

metrics = ("Accuracy", "F1")
results = {
    'Ours': (round(0.6617647058823529, 2), round(0.7570422535211268, 2)),
    'Original': (round(0.7916666666666666, 2), round(0.8590381426202321, 2)),
}

x = np.arange(len(metrics))  # the label locations
width = 0.25  # the width of the bars
multiplier = 0.5

fig, ax = plt.subplots(layout='constrained')

for attribute, measurement in results.items():
    offset = width * multiplier
    rects = ax.bar(x + offset, measurement, width, label=attribute)
    ax.bar_label(rects, padding=2)
    multiplier += 1

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_title('Microsoft Research Paraphrase Corpus (MRPC)')
ax.set_xticks(x + width, metrics)
ax.legend(loc='upper left', ncols=2)
ax.set_ylim(0, 1)
plt.rcParams["figure.figsize"] = (5,5)
name_file: str = "MRPC.jpg"
path_save: str = os.path.join('figures', name_file)
plt.savefig(path_save)
plt.show()

# %% [markdown]
# # COLA

# %%
result_json['cola']
# Out:
# {'ours': {'matthews_correlation': 0.12470316496270518},
#  'theirs': {'matthews_correlation': 0.3585568267218103}}

# %%
import matplotlib.pyplot as plt
import numpy as np

metrics = ["Matthews Correlation Coefficient)"]
results = {
    'Ours': (round(0.12470316496270518, 2)),
    'Original': (round(0.3585568267218103, 2)),
}

x = np.arange(len(metrics))  # the label locations
width = 0.25  # the width of the bars
multiplier = 0.5

fig, ax = plt.subplots(layout='constrained')

for attribute, measurement in results.items():
    offset = width * multiplier
    rects = ax.bar(x + offset, measurement, width, label=attribute)
    ax.bar_label(rects, padding=2)
    multiplier += 1

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_title('The Corpus of Linguistic Acceptability (COLA)')
ax.set_xticks(x + width, metrics)
ax.legend(loc='upper left', ncols=1)
ax.set_ylim(0, 1)
plt.rcParams["figure.figsize"] = (5,5)
name_file: str = "COLA.jpg"
path_save: str = os.path.join('figures', name_file)
plt.savefig(path_save)
plt.show()

# %% [markdown]
# # WNLI

# %%
result_json['wnli']
# Out:
# {'ours': {'accuracy': 0.4084507042253521},
#  'theirs': {'accuracy': 0.1267605633802817}}

# %%
import matplotlib.pyplot as plt
import numpy as np

metrics = ["Accuracy"]
results = {
    'Ours': (round(0.4084507042253521, 2)),
    'Original': (round(0.1267605633802817, 2)),
}

x = np.arange(len(metrics))  # the label locations
width = 0.25  # the width of the bars
multiplier = 0.5

fig, ax = plt.subplots(layout='constrained')

for attribute, measurement in results.items():
    offset = width * multiplier
    rects = ax.bar(x + offset, measurement, width, label=attribute)
    ax.bar_label(rects, padding=2)
    multiplier += 1

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_title('Winograd NLI (WNLI)')
ax.set_xticks(x + width, metrics)
ax.legend(loc='upper left', ncols=1)
ax.set_ylim(0, 1)
plt.rcParams["figure.figsize"] = (5,5)
name_file: str = "WNLI.jpg"
path_save: str = os.path.join('figures', name_file)
plt.savefig(path_save)
plt.show()

# %% [markdown]
# # QNLI

# %%
result_json['qnli']
# Out:
# {'ours': {'accuracy': 0.57166392092257},
#  'theirs': {'accuracy': 0.8649093904448105}}

# %%
import matplotlib.pyplot as plt
import numpy as np

metrics = ["Accuracy"]
results = {
    'Ours': (round(0.57166392092257, 2)),
    'Original': (round(0.8649093904448105, 2)),
}

x = np.arange(len(metrics))  # the label locations
width = 0.25  # the width of the bars
multiplier = 0.5

fig, ax = plt.subplots(layout='constrained')

for attribute, measurement in results.items():
    offset = width * multiplier
    rects = ax.bar(x + offset, measurement, width, label=attribute)
    ax.bar_label(rects, padding=2)
    multiplier += 1

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_title('Question NLI (QNLI)')
ax.set_xticks(x + width, metrics)
ax.legend(loc='upper left', ncols=1)
ax.set_ylim(0, 1)
plt.rcParams["figure.figsize"] = (5,5)
name_file: str = "QNLI.jpg"
path_save: str = os.path.join('figures', name_file)
plt.savefig(path_save)
plt.show()

# %% [markdown]
# # QQP

# %%
result_json['qqp']
# Out:
# {'ours': {'accuracy': 0.8223596339351966, 'f1': 0.7712884529647792},
#  'theirs': {'accuracy': 0.8968340341330695, 'f1': 0.8626650423100984}}

# %%
import matplotlib.pyplot as plt
import numpy as np

metrics = ("Accuracy", "F1")
results = {
    'Ours': (round(0.8223596339351966, 2), round(0.7712884529647792, 2)),
    'Original': (round(0.8968340341330695, 2), round(0.8626650423100984, 2)),
}

x = np.arange(len(metrics))  # the label locations
width = 0.25  # the width of the bars
multiplier = 0.5

fig, ax = plt.subplots(layout='constrained')

for attribute, measurement in results.items():
    offset = width * multiplier
    rects = ax.bar(x + offset, measurement, width, label=attribute)
    ax.bar_label(rects, padding=2)
    multiplier += 1

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_title('Quora Question Pairs (QQP)')
ax.set_xticks(x + width, metrics)
ax.legend(loc='upper left', ncols=2)
ax.set_ylim(0, 1)
plt.rcParams["figure.figsize"] = (5,5)
name_file: str = "QQP.jpg"
path_save: str = os.path.join('figures', name_file)
plt.savefig(path_save)
plt.show()

# %% [markdown]
# # RTE

# %%
result_json['rte']
# Out:
# {'ours': {'accuracy': 0.5126353790613718},
#  'theirs': {'accuracy': 0.6462093862815884}}

# %%
import matplotlib.pyplot as plt
import numpy as np

metrics = ["Accuracy"]
results = {
    'Ours': (round(0.5126353790613718, 2)),
    'Original': (round(0.6462093862815884, 2)),
}

x = np.arange(len(metrics))  # the label locations
width = 0.25  # the width of the bars
multiplier = 0.5

fig, ax = plt.subplots(layout='constrained')

for attribute, measurement in results.items():
    offset = width * multiplier
    rects = ax.bar(x + offset, measurement, width, label=attribute)
    ax.bar_label(rects, padding=2)
    multiplier += 1

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_title('Recognizing Textual Entailment (RTE)')
ax.set_xticks(x + width, metrics)
ax.legend(loc='upper left', ncols=1)
ax.set_ylim(0, 1)
plt.rcParams["figure.figsize"] = (5,5)
name_file: str = "RTE.jpg"
path_save: str = os.path.join('figures', name_file)
plt.savefig(path_save)
plt.show()

# %% [markdown]
# # SST2

# %%
result_json['sst2']
# Out:
# {'ours': {'accuracy': 0.7947247706422018},
#  'theirs': {'accuracy': 0.8830275229357798}}

# %%
import matplotlib.pyplot as plt
import numpy as np

metrics = ["Accuracy"]
results = {
    'Ours': (round(0.7947247706422018, 2)),
    'Original': (round(0.8830275229357798, 2)),
}

x = np.arange(len(metrics))  # the label locations
width = 0.25  # the width of the bars
multiplier = 0.5

fig, ax = plt.subplots(layout='constrained')

for attribute, measurement in results.items():
    offset = width * multiplier
    rects = ax.bar(x + offset, measurement, width, label=attribute)
    ax.bar_label(rects, padding=2)
    multiplier += 1

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_title('The Stanford Sentiment Treebank (SST)')
ax.set_xticks(x + width, metrics)
ax.legend(loc='upper left', ncols=1)
ax.set_ylim(0, 1)
plt.rcParams["figure.figsize"] = (5,5)
name_file: str = "SST.jpg"
path_save: str = os.path.join('figures', name_file)
plt.savefig(path_save)
plt.show()
